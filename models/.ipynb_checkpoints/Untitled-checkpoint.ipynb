# %%
import pickle
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
with open( "loss_MSE_bei.pkl", "rb" ) as f:
    j = pickle.load(f)

# %%
plt.plot(j[:25])

# %%
with open( "loss_Cas_bei_1.pkl", "rb" ) as f:
    k = pickle.load(f)

# %%
plt.plot(k[:25])

# %%
with open( "loss_Cas_bei_0.5.pkl", "rb" ) as fil:
    last = pickle.load(fil)

# %%
plt.plot(last[:25])

# %%
data = pd.read_csv('../data/beijing_pm25.csv')

# %%
data.describe()
# Out:
#                  No          year         month           day          hour  \
# count  43824.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean   21912.500000   2012.000000      6.523549     15.727820     11.500000
# std    12651.043435      1.413842      3.448572      8.799425      6.922266
# min        1.000000   2010.000000      1.000000      1.000000      0.000000
# 25%    10956.750000   2011.000000      4.000000      8.000000      5.750000
# 50%    21912.500000   2012.000000      7.000000     16.000000     11.500000
# 75%    32868.250000   2013.000000     10.000000     23.000000     17.250000
# max    43824.000000   2014.000000     12.000000     31.000000     23.000000
#
#               pm2.5          DEWP          TEMP          PRES           Iws  \
# count  41757.000000  43824.000000  43824.000000  43824.000000  43824.000000
# mean      98.613215      1.817246     12.448521   1016.447654     23.889140
# ...

# %%
ser = data.groupby(by=['hour'])['pm2.5'].mean()
#ser.plot()
# Out:
#           No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  \
# 26568  26569  2013      1   12     0  374.0   -10  -9.0  1025.0   cv   0.89
# 26569  26570  2013      1   12     1  391.0   -11 -10.0  1025.0   SE   1.79
# 26570  26571  2013      1   12     2  442.0   -13 -12.0  1025.0   NE   1.79
# 26571  26572  2013      1   12     3  425.0   -12 -11.0  1025.0   SE   0.89
# 26572  26573  2013      1   12     4  442.0   -12 -11.0  1024.0   cv   0.89
# 26573  26574  2013      1   12     5  287.0   -12 -11.0  1024.0   cv   1.78
# 26574  26575  2013      1   12     6  275.0   -13 -10.0  1024.0   cv   2.67
# 26575  26576  2013      1   12     7  174.0   -14 -12.0  1024.0   cv   3.56
# 26576  26577  2013      1   12     8  278.0   -15 -13.0  1024.0   NW   1.79
# 26577  26578  2013      1   12     9    NaN   -12 -10.0  1024.0   NW   3.58
# 26578  26579  2013      1   12    10  319.0   -10  -6.0  1024.0   NW   5.37
# ...
