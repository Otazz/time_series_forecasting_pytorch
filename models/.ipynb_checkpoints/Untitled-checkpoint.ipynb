# %%
import pickle

# %%
with open( "loss_MSE_bike.pkl", "rb" ) as f:
    j = pickle.load(f)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(j[:50])

# %%
with open( "loss_Cas_bike.pkl", "rb" ) as f:
    k = pickle.load(f)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(k[:50])
