# %%
import pickle

# %%
with open( "loss_MSE.pkl", "rb" ) as f:
    j = pickle.load(f)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(j[:50])

# %%
with open( "loss.pkl", "rb" ) as f:
    k = pickle.load(f)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(k[:50])
