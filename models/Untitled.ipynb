# %%
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
with open( "loss_MSE_bei.pkl", "rb" ) as f:
    j = pickle.load(f)

# %%
plt.plot(j[:50])

# %%
with open( "loss_Cas_bei.pkl", "rb" ) as f:
    k = pickle.load(f)

# %%
plt.plot(k[:50])
